# %% [markdown]
# # iPython notebook - Daryna analysis - Conversions by website pages
#
#
# ## 1. Import libraries

# %%
# %matplotlib inline 

import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns #sets up styles and gives us more plotting options

# %% [markdown]
#  2. Settings

# %%
# Time period 24th Jan - 24th April (arbitrary )

# API credentials
# Email address 705762800217-compute@developer.gserviceaccount.com
# Key IDs 948ee8e2a420ef14a5d5a29bd35104fe2f1e6ed4

# %%
# open file. It is requested via API explorer using request parameters:

#Account: TMRW Tech Hub
#Property: TMRW
#View: All Web Site Data
#ids: ga:123303369
#start-date: 2017-01-24
#end-date: 2017-04-24

#metrics
#ga:sessions
#ga:sessionsWithEvent

#dimensions
#ga:pagePath

#sort
#-ga:sessionsWithEvent

#filter
#ga:sessions>10

# %%
# Open file
# original file exported from GA includes ga:pagePath,ga:sessions,ga:sessionsWithEvent
# Calculate "rate" as "Sessions with event"/"Sessions" for each page.

TMRW_events= pd.read_csv("files/tmrw_events.csv")
TMRW_events
# Out:
#             ga:pagePath  ga:sessions  ga:sessionsWithEvent
# 0                    '/         4436                    82
# 1       '/TMRW_FAQs.php          100                    26
# 2  '/TMRW_Byte_Cafe.php          218                    23
# 3   '/TMRW_the_team.php           99                    10
# 4    '/trainstrikes.php           13                     0
# 5     '/voteforbyte.php           31                     0

# %%
TMRW_events.columns=["page","sessions","events","rate"]
TMRW_events
# Out:
#                    page  sessions  rate
# 0                    '/      4436    82
# 1       '/TMRW_FAQs.php       100    26
# 2  '/TMRW_Byte_Cafe.php       218    23
# 3   '/TMRW_the_team.php        99    10
# 4    '/trainstrikes.php        13     0
# 5     '/voteforbyte.php        31     0

# %%
TMRW_events_filter = TMRW_events[TMRW_events.rate > 0]
TMRW_events_filter
# Out:
#                    page  sessions  rate
# 0                    '/      4436    82
# 1       '/TMRW_FAQs.php       100    26
# 2  '/TMRW_Byte_Cafe.php       218    23
# 3   '/TMRW_the_team.php        99    10

# %%
TMRW_events_filter.describe()
# Out:
#          sessions       rate
# count     4.00000   4.000000
# mean   1213.25000  35.250000
# std    2149.22612  31.930915
# min      99.00000  10.000000
# 25%      99.75000  19.750000
# 50%     159.00000  24.500000
# 75%    1272.50000  40.000000
# max    4436.00000  82.000000

# %%
#import numpy as np
from bokeh.io import output_notebook
from bokeh.charts import Bar, Line, show
from bokeh.plotting import figure, output_file, show

output_notebook()
p = Bar(TMRW_events_filter, 'page', values='rate', title="Events per page")
p.legend.location = "top_right"
# l = Bar(TMRW_events_filter, 'page', values='rate', title="Events per page")
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f22a8000-56b3-48d0-8fca-bd0907338d25">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="b41d3ae6-cc3b-4397-b544-9e4dd6e57c8a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b41d3ae6-cc3b-4397-b544-9e4dd6e57c8a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b41d3ae6-cc3b-4397-b544-9e4dd6e57c8a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b41d3ae6-cc3b-4397-b544-9e4dd6e57c8a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a86fa928-fcd0-48cd-951b-7643d677f21d":{"roots":{"references":[{"attributes":{"legends":[["'/",[{"id":"377426e7-0f77-4119-99d8-97cbe447fc87","type":"GlyphRenderer"}]],["'/TMRW_FAQs.php",[{"id":"894789ef-1d4a-439c-a442-1725f6fc0c7d","type":"GlyphRenderer"}]],["'/TMRW_Byte_Cafe.php",[{"id":"12a518e1-56f7-4b99-9e72-b7e944658b59","type":"GlyphRenderer"}]],["'/TMRW_the_team.php",[{"id":"68d8ed6b-c0b2-4765-b879-94a1e6c17dd5","type":"GlyphRenderer"}]]],"location":"top_right","plot":{"id":"2b2672a0-c5cc-43ae-abe5-4a3a315339ff","subtype":"Chart","type":"Plot"}},"id":"cdd83bb7-e8e9-4f9b-bb9a-89f160664f78","type":"Legend"},{"attributes":{"plot":{"id":"2b2672a0-c5cc-43ae-abe5-4a3a315339ff","subtype":"Chart","type":"Plot"}},"id":"97992d7c-e33c-4671-a9ad-0d97d52556e3","type":"HelpTool"},{"attributes":{},"id":"1c99e7de-3619-49e5-beb2-d450b4186582","type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"2b2672a0-c5cc-43ae-abe5-4a3a315339ff","subtype":"Chart","type":"Plot"},"ticker":{"id":"c6b565ac-e440-4455-a5c6-b5db67dfac95","type":"BasicTicker"}},"id":"0965209f-8441-427b-95a8-31689d07b896","type":"Grid"},{"attributes":{"callback":null,"column_names":["color","height","label","y","fill_alpha","line_color","x","line_alpha","width"],"data":{"chart_index":[{"page":"'/"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[82.0],"label":[{"page":"'/"}],"line_alpha":[1.0],"line_color":["white"],"page":["'/"],"width":[0.8],"x":["'/"],"y":[41.0]}},"id":"fdd1ef5f-1b09-45f6-80a9-75bd8c34ba06","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":86.1},"id":"4448feb4-06b6-4d29-bbd3-5f00ed06bc03","type":"Range1d"},{"attributes":{"overlay":{"id":"9b3f3c31-3aa2-45b0-9074-8608fcb40740","type":"BoxAnnotation"},"plot":{"id":"2b2672a0-c5cc-43ae-abe5-4a3a315339ff","subtype":"Chart","type":"Plot"}},"id":"01817b0e-eee0-4597-9b7d-8a879ec4f75d","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"66cf7065-3f0c-4873-91d9-9b5e3a540885","type":"ColumnDataSource"},"glyph":{"id":"45107923-285d-4c8b-9616-0f982eae0213","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"68d8ed6b-c0b2-4765-b879-94a1e6c17dd5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"45107923-285d-4c8b-9616-0f982eae0213","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","height","label","y","fill_alpha","line_color","x","line_alpha","width"],"data":{"chart_index":[{"page":"'/TMRW_FAQs.php"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[26.0],"label":[{"page":"'/TMRW_FAQs.php"}],"line_alpha":[1.0],"line_color":["white"],"page":["'/TMRW_FAQs.php"],"width":[0.8],"x":["'/TMRW_FAQs.php"],"y":[13.0]}},"id":"d3a52a93-1e3c-4632-a5d0-ac8bb8e3bab9","type":"ColumnDataSource"},{"attributes":{},"id":"e92e58d6-36e2-4f37-8a1a-9a16878932ab","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2b2672a0-c5cc-43ae-abe5-4a3a315339ff","subtype":"Chart","type":"Plot"}},"id":"67ff6062-84bb-4de5-b900-7560e25f1ee2","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9b3f3c31-3aa2-45b0-9074-8608fcb40740","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a6f6da64-87b9-4c06-a4f8-26dd3655ab7c","type":"Rect"},{"attributes":{"plot":null,"text":"Events per page"},"id":"a1ac1d3c-7cba-4163 ...

# %%
TMRW_events_data = TMRW_events_filter.groupby(['page']).mean()
TMRW_events_data
# Out:
#                       sessions  rate
# page
# '/                        4436    82
# '/TMRW_Byte_Cafe.php       218    23
# '/TMRW_FAQs.php            100    26
# '/TMRW_the_team.php         99    10

# %%
selected=TMRW_events_data.loc[:,"rate"]
selected
# Out:
# page
# '/                      82
# '/TMRW_Byte_Cafe.php    23
# '/TMRW_FAQs.php         26
# '/TMRW_the_team.php     10
# Name: rate, dtype: int64

# %%
labels = selected.index
sizes = TMRW_events_filter['rate']
colors = ['green','yellow', 'red', 'lightskyblue']
explode = (0, 0, 0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=False, startangle=90)
#plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.title('Conversions by pages                                    ')
plt.tight_layout()
plt.show()
